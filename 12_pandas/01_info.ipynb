# %%
import pandas as pd

# %%
df = pd.read_csv("../files/survey_results_public.csv")

# %%
# rows and cols count
df.shape

# %%
# header names
df.columns

# %%
# data type of headers
df.dtypes

# %%
df.info()

# %%
# get the first # (default 5) rows
df.head(3)

# %%
# get the last x (default 5) rows
df.tail(10)

# %%
df.describe()

# %%
df.isna().sum()

# %%
pd.set_option("display.max_columns", 10)
pd.set_option("display.max_rows", 10)
df

# %%
df.memory_usage(deep=True)

# %%
total_bytes = df.memory_usage(deep=True).sum()
total_mb = total_bytes / (1024 * 1024)
total_mb
