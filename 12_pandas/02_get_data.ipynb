# %%
import pandas as pd

# %%
df = pd.read_csv("../files/survey_results_public.csv")

# %%
df.columns
# Out:
# Index(['Respondent', 'MainBranch', 'Hobbyist', 'Age', 'Age1stCode', 'CompFreq',
#        'CompTotal', 'ConvertedComp', 'Country', 'CurrencyDesc',
#        'CurrencySymbol', 'DatabaseDesireNextYear', 'DatabaseWorkedWith',
#        'DevType', 'EdLevel', 'Employment', 'Ethnicity', 'Gender', 'JobFactors',
#        'JobSat', 'JobSeek', 'LanguageDesireNextYear', 'LanguageWorkedWith',
#        'MiscTechDesireNextYear', 'MiscTechWorkedWith',
#        'NEWCollabToolsDesireNextYear', 'NEWCollabToolsWorkedWith', 'NEWDevOps',
#        'NEWDevOpsImpt', 'NEWEdImpt', 'NEWJobHunt', 'NEWJobHuntResearch',
#        'NEWLearn', 'NEWOffTopic', 'NEWOnboardGood', 'NEWOtherComms',
#        'NEWOvertime', 'NEWPurchaseResearch', 'NEWPurpleLink', 'NEWSOSites',
#        'NEWStuck', 'OpSys', 'OrgSize', 'PlatformDesireNextYear',
#        'PlatformWorkedWith', 'PurchaseWhat', 'Sexuality', 'SOAccount',
#        'SOComm', 'SOPartFreq', 'SOVisitFreq', 'SurveyEase', 'SurveyLength',
# ...

# %%
df["Country"]
# Out:
# 0                   Germany
# 1            United Kingdom
# 2        Russian Federation
# 3                   Albania
# 4             United States
#                 ...
# 64456         United States
# 64457               Morocco
# 64458              Viet Nam
# 64459                Poland
# 64460                 Spain
# Name: Country, Length: 64461, dtype: object

# %%
df["Age"].value_counts()
# Out:
# Age
# 25.0    2693
# 28.0    2412
# 30.0    2406
# 26.0    2391
# 27.0    2338
#         ...
# 88.0       1
# 16.5       1
# 23.4       1
# 95.0       1
# 14.5       1
# Name: count, Length: 110, dtype: int64

# %%
# label based indexing: cimke alapú
# 0 a DataFrame indexének az értékére utal, nem pedig a sor pozícióra
df.loc[0]
# Out:
# Respondent                                                  1
# MainBranch                     I am a developer by profession
# Hobbyist                                                  Yes
# Age                                                       NaN
# Age1stCode                                                 13
#                                        ...
# WebframeWorkedWith                       ASP.NET;ASP.NET Core
# WelcomeChange         Just as welcome now as I felt last year
# WorkWeekHrs                                              50.0
# YearsCode                                                  36
# YearsCodePro                                               27
# Name: 0, Length: 61, dtype: object

# %%
df.loc[0, "Country"]
# Out:
# 'Germany'

# %%
df.loc[[0, 10, 100], "Country"]
# Out:
# 0             Germany
# 10     United Kingdom
# 100    United Kingdom
# Name: Country, dtype: object

# %%
df.loc[12:18, "Country"]
# Out:
# 12       Netherlands
# 13     United States
# 14            France
# 15    United Kingdom
# 16     United States
# 17     United States
# 18     United States
# Name: Country, dtype: object

# %%
df.loc[12:18, ["Country", "Age", "YearsCodePro"]]
# Out:
#            Country   Age YearsCodePro
# 12     Netherlands  53.0           20
# 13   United States  27.0            1
# 14          France   NaN          NaN
# 15  United Kingdom  45.0           23
# 16   United States  25.0            3
# 17   United States  32.0           12
# 18   United States  24.0            3

# %%
df.loc[12:18, "Country":"YearsCodePro"]
# Out:
#            Country          CurrencyDesc CurrencySymbol  \
# 12     Netherlands         European Euro            EUR
# 13   United States  United States dollar            USD
# 14          France                   NaN            NaN
# 15  United Kingdom        Pound sterling            GBP
# 16   United States  United States dollar            USD
# 17   United States  United States dollar            USD
# 18   United States  United States dollar            USD
#
#                               DatabaseDesireNextYear  \
# 12                                               NaN
# 13                     Firebase;Microsoft SQL Server
# 14                                               NaN
# 15                                               NaN
# 16  Cassandra;Elasticsearch;MariaDB;PostgreSQL;Redis
# 17             Elasticsearch;PostgreSQL;Redis;SQLite
# 18                                   MariaDB;MongoDB
#
#                           DatabaseWorkedWith  \
# ...

# %%
# position based indexing (faster)
# integer based
# A 0 a Dataframe 1. sorának pozíciójára utal, függetlenül az index értéktől
df.iloc[0:10, 5:10]
# Out:
#   CompFreq  CompTotal  ConvertedComp             Country          CurrencyDesc
# 0  Monthly        NaN            NaN             Germany         European Euro
# 1      NaN        NaN            NaN      United Kingdom        Pound sterling
# 2      NaN        NaN            NaN  Russian Federation                   NaN
# 3      NaN        NaN            NaN             Albania          Albanian lek
# 4      NaN        NaN            NaN       United States                   NaN
# 5      NaN        NaN            NaN             Germany         European Euro
# 6  Monthly        NaN            NaN               India  United States dollar
# 7   Yearly   116000.0       116000.0       United States  United States dollar
# 8      NaN        NaN            NaN             Tunisia  United States dollar
# 9   Yearly    25000.0        32315.0      United Kingdom        Pound sterling

# %%
# Boolean indexelés, feltéel alapján
df["YearsCodePro"] = pd.to_numeric(df["YearsCodePro"], errors="coerce")
df[df["YearsCodePro"] > 10]
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1                     I am a developer by profession      Yes
# 7               8                     I am a developer by profession      Yes
# 12             13  I am not primarily a developer, but I write co...      Yes
# 15             16                     I am a developer by profession      Yes
# 17             18                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 64376       51773                                                NaN      Yes
# 64392       55074                                                NaN      Yes
# 64407       57084                                                NaN      Yes
# 64415       58819                                                NaN      Yes
# 64427       60149                                                NaN      Yes
#
# ...

# %%
# query - SQL like
df.query('YearsCodePro > 5 and WebframeWorkedWith.str.contains("React", na=False)')
# Out:
#        Respondent                      MainBranch Hobbyist   Age Age1stCode  \
# 15             16  I am a developer by profession      Yes  45.0          8
# 25             26  I am a developer by profession       No   NaN         12
# 32             33  I am a developer by profession      Yes  39.0         14
# 37             38  I am a developer by profession       No  35.0         14
# 41             42  I am a developer by profession       No  32.0         14
# ...           ...                             ...      ...   ...        ...
# 64053       65523  I am a developer by profession      Yes   NaN         18
# 64096       65567  I am a developer by profession      Yes   NaN         12
# 64152       65629  I am a developer by profession      Yes  41.0         15
# 64230       18748                             NaN      Yes   NaN         30
# 64392       55074                             NaN      Yes  36.0         35
#
# ...

# %%
# grouping
country_groups = df.groupby('Country')
country_groups.get_group('Hungary')
# Out:
#        Respondent                              MainBranch Hobbyist   Age  \
# 169           171          I am a developer by profession      Yes  31.0
# 314           316  I am a student who is learning to code      Yes  17.0
# 366           368             I code primarily as a hobby      Yes   NaN
# 414           416          I am a developer by profession      Yes  31.0
# 620           622          I am a developer by profession      Yes  27.0
# ...           ...                                     ...      ...   ...
# 63622       65047          I am a developer by profession      Yes   NaN
# 64016       65480          I am a developer by profession      Yes   NaN
# 64125       65600          I am a developer by profession       No   NaN
# 64199       11739                                     NaN      Yes  35.0
# 64266       28425                                     NaN      Yes   NaN
#
#       Age1stCode CompFreq  CompTotal  ConvertedComp  Country  \
# ...
