# %%
import pandas as pd
import requests

# %%
df = pd.read_csv('../files/employees-with-header.csv', sep=",", header=0, index_col='id', usecols=['id','email_address'], nrows=100)

# %%
df

# %%
response = requests.get(
    "https://api.github.com/repos/pandas-dev/pandas/issues?per_page=5"
)
data = response.json()
df_api = pd.json_normalize(data)
df_api_selected = df_api[["id", "number", "title"]]
df_api_selected
